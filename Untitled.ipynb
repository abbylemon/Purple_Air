# %%
import requests
import pandas as pd
import gmaps

from config import gkey

# %%
base_url = "https://www.purpleair.com/json"
response = requests.get(base_url)
puruple_air = response.json()

puruple_air['results'][0]
# Out:
# {'ID': 14633,
#  'Label': ' Hazelwood canary ',
#  'DEVICE_LOCATIONTYPE': 'outside',
#  'THINGSPEAK_PRIMARY_ID': '559921',
#  'THINGSPEAK_PRIMARY_ID_READ_KEY': 'CU4BQZZ38WO5UJ4C',
#  'THINGSPEAK_SECONDARY_ID': '559922',
#  'THINGSPEAK_SECONDARY_ID_READ_KEY': 'D0YNZ1LM59LL49VQ',
#  'Lat': 37.275561,
#  'Lon': -121.964134,
#  'PM2_5Value': '1.52',
#  'LastSeen': 1579024103,
#  'Type': 'PMS5003+PMS5003+BME280',
#  'Hidden': 'false',
#  'isOwner': 0,
#  'humidity': '45',
#  'temp_f': '63',
#  'pressure': '1018.67',
#  'AGE': 1,
#  'Stats': '{"v":1.52,"v1":0.8,"v2":0.57,"v3":0.46,"v4":0.9,"v5":2.86,"v6":5.67,"pm":1.52,"lastModified":1579024103744,"timeSinceModified":120127}'}

# %%
purple_air_df = pd.DataFrame()
purple_air_df["Index"] = [x for x in range(10000)]
purple_air_df["Device ID"] = ""
purple_air_df["Latitude"] = ""
purple_air_df["Longitude"] = ""
purple_air_df["PM2_5 Value"] = ""
purple_air_df['Humidity'] = ""
purple_air_df["Temperature (F)"] = ""
purple_air_df["Pressure"] = ""


for x in range(10000):
    try:
        print(f"Pulling data from PurpleAir Device ID {puruple_air['results'][x]['ID']}")
        
        purple_air_df.loc[x, 'Device ID'] = puruple_air['results'][x]['ID']
        purple_air_df.loc[x, 'Latitude'] = puruple_air['results'][x]['Lat']
        purple_air_df.loc[x, 'Longitude'] = puruple_air['results'][x]['Lon']
        purple_air_df.loc[x, 'PM2_5 Value'] = puruple_air['results'][x]['PM2_5Value']
        purple_air_df.loc[x, 'Humidity'] = puruple_air['results'][x]['humidity']
        purple_air_df.loc[x, 'Temperature (F)'] = puruple_air['results'][x]['temp_f']
        purple_air_df.loc[x, 'Pressure'] = puruple_air['results'][x]['pressure']

    except:
        print("Missing field/results... skipping.")
        
    print("--------------------------------")
# Out:
# Pulling data from PurpleAir Device ID 14633
# --------------------------------
# Pulling data from PurpleAir Device ID 14634
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25999
# --------------------------------
# Pulling data from PurpleAir Device ID 26000
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 16931
# --------------------------------
# Pulling data from PurpleAir Device ID 16932
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22751
# --------------------------------
# Pulling data from PurpleAir Device ID 22752
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2492
# --------------------------------
# Pulling data from PurpleAir Device ID 2493
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30755
# --------------------------------
# Pulling data from PurpleAir Device ID 30756
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26941
# --------------------------------
# Pulling data from PurpleAir Device ID 26942
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18943
# --------------------------------
# Pulling data from PurpleAir Device ID 18944
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12248
# --------------------------------
# Pulling data from PurpleAir Device ID 12249
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 10808
# --------------------------------
# Pulling data from PurpleAir Device ID 10809
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37569
# --------------------------------
# Pulling data from PurpleAir Device ID 37570
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24993
# --------------------------------
# Pulling data from PurpleAir Device ID 24994
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20747
# --------------------------------
# Pulling data from PurpleAir Device ID 20748
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37077
# --------------------------------
# Pulling data from PurpleAir Device ID 37078
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5460
# --------------------------------
# Pulling data from PurpleAir Device ID 5461
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23943
# --------------------------------
# Pulling data from PurpleAir Device ID 23944
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 9014
# --------------------------------
# Pulling data from PurpleAir Device ID 9015
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2776
# --------------------------------
# Pulling data from PurpleAir Device ID 2777
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2890
# --------------------------------
# Pulling data from PurpleAir Device ID 2891
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 40763
# --------------------------------
# Pulling data from PurpleAir Device ID 40764
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21249
# --------------------------------
# Pulling data from PurpleAir Device ID 21250
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 39789
# --------------------------------
# Pulling data from PurpleAir Device ID 39790
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37971
# --------------------------------
# Pulling data from PurpleAir Device ID 37972
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 32587
# --------------------------------
# Pulling data from PurpleAir Device ID 32588
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5588
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5589
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 29465
# --------------------------------
# Pulling data from PurpleAir Device ID 29466
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 29857
# --------------------------------
# Pulling data from PurpleAir Device ID 29858
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 13143
# --------------------------------
# Pulling data from PurpleAir Device ID 13144
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43069
# --------------------------------
# Pulling data from PurpleAir Device ID 43070
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5416
# --------------------------------
# Pulling data from PurpleAir Device ID 5417
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17281
# --------------------------------
# Pulling data from PurpleAir Device ID 17282
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 32553
# --------------------------------
# Pulling data from PurpleAir Device ID 32554
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20893
# --------------------------------
# Pulling data from PurpleAir Device ID 20894
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 16863
# --------------------------------
# Pulling data from PurpleAir Device ID 16864
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17393
# --------------------------------
# Pulling data from PurpleAir Device ID 17394
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19839
# --------------------------------
# Pulling data from PurpleAir Device ID 19840
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4928
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4929
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15477
# --------------------------------
# Pulling data from PurpleAir Device ID 15478
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31185
# --------------------------------
# Pulling data from PurpleAir Device ID 31186
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19837
# --------------------------------
# Pulling data from PurpleAir Device ID 19838
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37121
# --------------------------------
# Pulling data from PurpleAir Device ID 37122
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 3479
# --------------------------------
# Pulling data from PurpleAir Device ID 3480
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 38831
# --------------------------------
# Pulling data from PurpleAir Device ID 38832
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23285
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23286
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 42531
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 42532
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31583
# --------------------------------
# Pulling data from PurpleAir Device ID 31584
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6786
# --------------------------------
# Pulling data from PurpleAir Device ID 6787
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24785
# --------------------------------
# Pulling data from PurpleAir Device ID 24786
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 35725
# --------------------------------
# Pulling data from PurpleAir Device ID 35726
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 8014
# --------------------------------
# Pulling data from PurpleAir Device ID 8015
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34103
# --------------------------------
# Pulling data from PurpleAir Device ID 34104
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5216
# --------------------------------
# Pulling data from PurpleAir Device ID 5217
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21317
# --------------------------------
# Pulling data from PurpleAir Device ID 21318
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21205
# --------------------------------
# Pulling data from PurpleAir Device ID 21206
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4101
# --------------------------------
# Pulling data from PurpleAir Device ID 4102
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 944
# --------------------------------
# Pulling data from PurpleAir Device ID 945
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 8964
# --------------------------------
# Pulling data from PurpleAir Device ID 8965
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34265
# --------------------------------
# Pulling data from PurpleAir Device ID 34266
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20679
# --------------------------------
# Pulling data from PurpleAir Device ID 20680
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24767
# --------------------------------
# Pulling data from PurpleAir Device ID 24768
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 41681
# --------------------------------
# Pulling data from PurpleAir Device ID 41682
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 40505
# --------------------------------
# Pulling data from PurpleAir Device ID 40506
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37725
# --------------------------------
# Pulling data from PurpleAir Device ID 37726
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 39861
# --------------------------------
# Pulling data from PurpleAir Device ID 39862
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22489
# --------------------------------
# Pulling data from PurpleAir Device ID 22490
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21435
# --------------------------------
# Pulling data from PurpleAir Device ID 21438
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30809
# --------------------------------
# Pulling data from PurpleAir Device ID 30810
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30777
# --------------------------------
# Pulling data from PurpleAir Device ID 30778
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 11698
# --------------------------------
# Pulling data from PurpleAir Device ID 11699
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12244
# --------------------------------
# Pulling data from PurpleAir Device ID 12245
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20543
# --------------------------------
# Pulling data from PurpleAir Device ID 20544
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17781
# --------------------------------
# Pulling data from PurpleAir Device ID 17782
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 11194
# --------------------------------
# Pulling data from PurpleAir Device ID 11195
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 3960
# --------------------------------
# Pulling data from PurpleAir Device ID 3961
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 16915
# --------------------------------
# Pulling data from PurpleAir Device ID 16916
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 35151
# --------------------------------
# Pulling data from PurpleAir Device ID 35152
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5506
# --------------------------------
# Pulling data from PurpleAir Device ID 5507
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28669
# --------------------------------
# Pulling data from PurpleAir Device ID 28670
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 9638
# --------------------------------
# Pulling data from PurpleAir Device ID 9639
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 29109
# --------------------------------
# Pulling data from PurpleAir Device ID 29110
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5090
# --------------------------------
# Pulling data from PurpleAir Device ID 5091
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21457
# --------------------------------
# Pulling data from PurpleAir Device ID 21458
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 29913
# --------------------------------
# Pulling data from PurpleAir Device ID 29914
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19945
# --------------------------------
# Pulling data from PurpleAir Device ID 19946
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25285
# --------------------------------
# Pulling data from PurpleAir Device ID 25286
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22265
# --------------------------------
# Pulling data from PurpleAir Device ID 22266
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19335
# --------------------------------
# Pulling data from PurpleAir Device ID 19336
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36597
# --------------------------------
# Pulling data from PurpleAir Device ID 36598
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12839
# --------------------------------
# Pulling data from PurpleAir Device ID 12840
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20709
# --------------------------------
# Pulling data from PurpleAir Device ID 20710
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21269
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21270
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 40635
# --------------------------------
# Pulling data from PurpleAir Device ID 40636
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23965
# --------------------------------
# Pulling data from PurpleAir Device ID 23966
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4541
# --------------------------------
# Pulling data from PurpleAir Device ID 4542
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 33653
# --------------------------------
# Pulling data from PurpleAir Device ID 33654
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28907
# --------------------------------
# Pulling data from PurpleAir Device ID 28908
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34653
# --------------------------------
# Pulling data from PurpleAir Device ID 34654
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17413
# --------------------------------
# Pulling data from PurpleAir Device ID 41037
# --------------------------------
# Pulling data from PurpleAir Device ID 41038
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17414
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34519
# --------------------------------
# Pulling data from PurpleAir Device ID 34520
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15669
# --------------------------------
# Pulling data from PurpleAir Device ID 15670
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43861
# --------------------------------
# Pulling data from PurpleAir Device ID 43862
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26799
# --------------------------------
# Pulling data from PurpleAir Device ID 26800
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 3186
# --------------------------------
# Pulling data from PurpleAir Device ID 3187
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 33157
# --------------------------------
# Pulling data from PurpleAir Device ID 33158
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 35307
# --------------------------------
# Pulling data from PurpleAir Device ID 35308
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 1517
# --------------------------------
# Pulling data from PurpleAir Device ID 1518
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22799
# --------------------------------
# Pulling data from PurpleAir Device ID 22800
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 10806
# --------------------------------
# Pulling data from PurpleAir Device ID 10807
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27023
# --------------------------------
# Pulling data from PurpleAir Device ID 27024
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 10238
# --------------------------------
# Pulling data from PurpleAir Device ID 10239
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26801
# --------------------------------
# Pulling data from PurpleAir Device ID 26802
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12959
# --------------------------------
# Pulling data from PurpleAir Device ID 12960
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19881
# --------------------------------
# Pulling data from PurpleAir Device ID 19882
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23465
# --------------------------------
# Pulling data from PurpleAir Device ID 23466
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17981
# --------------------------------
# Pulling data from PurpleAir Device ID 17982
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30741
# --------------------------------
# Pulling data from PurpleAir Device ID 30742
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30875
# --------------------------------
# Pulling data from PurpleAir Device ID 30876
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31131
# --------------------------------
# Pulling data from PurpleAir Device ID 31132
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24127
# --------------------------------
# Pulling data from PurpleAir Device ID 24128
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24141
# --------------------------------
# Pulling data from PurpleAir Device ID 24142
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24029
# --------------------------------
# Pulling data from PurpleAir Device ID 24030
# --------------------------------
# Pulling data from PurpleAir Device ID 41075
# --------------------------------
# Pulling data from PurpleAir Device ID 41076
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25611
# --------------------------------
# Pulling data from PurpleAir Device ID 25612
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22529
# --------------------------------
# Pulling data from PurpleAir Device ID 22530
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 11076
# --------------------------------
# Pulling data from PurpleAir Device ID 11077
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 42545
# --------------------------------
# Pulling data from PurpleAir Device ID 42546
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 8988
# --------------------------------
# Pulling data from PurpleAir Device ID 8989
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 42195
# --------------------------------
# Pulling data from PurpleAir Device ID 42196
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4187
# --------------------------------
# Pulling data from PurpleAir Device ID 4188
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21277
# --------------------------------
# Pulling data from PurpleAir Device ID 21278
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 32937
# --------------------------------
# Pulling data from PurpleAir Device ID 32938
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19091
# --------------------------------
# Pulling data from PurpleAir Device ID 19092
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5616
# --------------------------------
# Pulling data from PurpleAir Device ID 5617
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6434
# --------------------------------
# Pulling data from PurpleAir Device ID 6435
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4135
# --------------------------------
# Pulling data from PurpleAir Device ID 4136
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 8690
# --------------------------------
# Pulling data from PurpleAir Device ID 8691
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43603
# --------------------------------
# Pulling data from PurpleAir Device ID 43604
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 39215
# --------------------------------
# Pulling data from PurpleAir Device ID 39216
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 38517
# --------------------------------
# Pulling data from PurpleAir Device ID 44677
# --------------------------------
# Pulling data from PurpleAir Device ID 38518
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 44678
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36199
# --------------------------------
# Pulling data from PurpleAir Device ID 36200
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23107
# --------------------------------
# Pulling data from PurpleAir Device ID 23453
# --------------------------------
# Pulling data from PurpleAir Device ID 23108
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23454
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18761
# --------------------------------
# Pulling data from PurpleAir Device ID 18762
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30403
# --------------------------------
# Pulling data from PurpleAir Device ID 30404
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36141
# --------------------------------
# Pulling data from PurpleAir Device ID 36142
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26971
# --------------------------------
# Pulling data from PurpleAir Device ID 26972
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17645
# --------------------------------
# Pulling data from PurpleAir Device ID 17646
# --------------------------------
# Pulling data from PurpleAir Device ID 20765
# --------------------------------
# Pulling data from PurpleAir Device ID 20766
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5778
# --------------------------------
# Pulling data from PurpleAir Device ID 5779
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25019
# --------------------------------
# Pulling data from PurpleAir Device ID 25020
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22881
# --------------------------------
# Pulling data from PurpleAir Device ID 22882
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 3986
# --------------------------------
# Pulling data from PurpleAir Device ID 3987
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19985
# --------------------------------
# Pulling data from PurpleAir Device ID 19986
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23471
# --------------------------------
# Pulling data from PurpleAir Device ID 23472
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 7562
# --------------------------------
# Pulling data from PurpleAir Device ID 7563
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36673
# --------------------------------
# Pulling data from PurpleAir Device ID 36674
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 29869
# --------------------------------
# Pulling data from PurpleAir Device ID 29870
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 14573
# --------------------------------
# Pulling data from PurpleAir Device ID 14574
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 33235
# --------------------------------
# Pulling data from PurpleAir Device ID 33236
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28849
# --------------------------------
# Pulling data from PurpleAir Device ID 28850
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43407
# --------------------------------
# Pulling data from PurpleAir Device ID 43408
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22069
# --------------------------------
# Pulling data from PurpleAir Device ID 22070
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23191
# --------------------------------
# Pulling data from PurpleAir Device ID 23192
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26193
# --------------------------------
# Pulling data from PurpleAir Device ID 26194
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34161
# --------------------------------
# Pulling data from PurpleAir Device ID 29861
# --------------------------------
# Pulling data from PurpleAir Device ID 34162
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 29862
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28675
# --------------------------------
# Pulling data from PurpleAir Device ID 28676
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6608
# --------------------------------
# Pulling data from PurpleAir Device ID 6609
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37363
# --------------------------------
# Pulling data from PurpleAir Device ID 37364
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2977
# --------------------------------
# Pulling data from PurpleAir Device ID 2978
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2974
# --------------------------------
# Pulling data from PurpleAir Device ID 2975
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2982
# --------------------------------
# Pulling data from PurpleAir Device ID 2983
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2980
# --------------------------------
# Pulling data from PurpleAir Device ID 2981
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28487
# --------------------------------
# Pulling data from PurpleAir Device ID 28488
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 10014
# --------------------------------
# Pulling data from PurpleAir Device ID 10015
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 38665
# --------------------------------
# Pulling data from PurpleAir Device ID 38666
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28227
# --------------------------------
# Pulling data from PurpleAir Device ID 28228
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 35375
# --------------------------------
# Pulling data from PurpleAir Device ID 35376
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18659
# --------------------------------
# Pulling data from PurpleAir Device ID 18660
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 32545
# --------------------------------
# Pulling data from PurpleAir Device ID 32546
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37069
# --------------------------------
# Pulling data from PurpleAir Device ID 37070
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 41503
# --------------------------------
# Pulling data from PurpleAir Device ID 41504
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19693
# --------------------------------
# Pulling data from PurpleAir Device ID 19694
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 35181
# --------------------------------
# Pulling data from PurpleAir Device ID 35182
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27047
# --------------------------------
# Pulling data from PurpleAir Device ID 27048
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43519
# --------------------------------
# Pulling data from PurpleAir Device ID 43520
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25463
# --------------------------------
# Pulling data from PurpleAir Device ID 25464
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25161
# --------------------------------
# Pulling data from PurpleAir Device ID 25162
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 9546
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 9547
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43955
# --------------------------------
# Pulling data from PurpleAir Device ID 43956
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25775
# --------------------------------
# Pulling data from PurpleAir Device ID 25776
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22117
# --------------------------------
# Pulling data from PurpleAir Device ID 22118
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37081
# --------------------------------
# Pulling data from PurpleAir Device ID 37082
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20151
# --------------------------------
# Pulling data from PurpleAir Device ID 20152
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20461
# --------------------------------
# Pulling data from PurpleAir Device ID 20462
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 38371
# --------------------------------
# Pulling data from PurpleAir Device ID 38372
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37417
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37418
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12811
# --------------------------------
# Pulling data from PurpleAir Device ID 12812
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24123
# --------------------------------
# Pulling data from PurpleAir Device ID 24124
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19807
# --------------------------------
# Pulling data from PurpleAir Device ID 19808
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 7002
# --------------------------------
# Pulling data from PurpleAir Device ID 7003
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 9578
# --------------------------------
# Pulling data from PurpleAir Device ID 9579
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21303
# --------------------------------
# Pulling data from PurpleAir Device ID 21304
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22575
# --------------------------------
# Pulling data from PurpleAir Device ID 22576
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5125
# --------------------------------
# Pulling data from PurpleAir Device ID 5126
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12052
# --------------------------------
# Pulling data from PurpleAir Device ID 12053
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 24851
# --------------------------------
# Pulling data from PurpleAir Device ID 30853
# --------------------------------
# Pulling data from PurpleAir Device ID 24852
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30854
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 11286
# --------------------------------
# Pulling data from PurpleAir Device ID 11287
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19181
# --------------------------------
# Pulling data from PurpleAir Device ID 19182
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43585
# --------------------------------
# Pulling data from PurpleAir Device ID 43586
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 3503
# --------------------------------
# Pulling data from PurpleAir Device ID 3504
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15127
# --------------------------------
# Pulling data from PurpleAir Device ID 15339
# --------------------------------
# Pulling data from PurpleAir Device ID 15128
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15340
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26379
# --------------------------------
# Pulling data from PurpleAir Device ID 26380
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19857
# --------------------------------
# Pulling data from PurpleAir Device ID 19858
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 7946
# --------------------------------
# Pulling data from PurpleAir Device ID 7947
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 40249
# --------------------------------
# Pulling data from PurpleAir Device ID 40250
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 41473
# --------------------------------
# Pulling data from PurpleAir Device ID 36355
# --------------------------------
# Pulling data from PurpleAir Device ID 41474
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36356
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15467
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15468
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43527
# --------------------------------
# Pulling data from PurpleAir Device ID 43528
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15465
# --------------------------------
# Pulling data from PurpleAir Device ID 15466
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6238
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6239
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 14849
# --------------------------------
# Pulling data from PurpleAir Device ID 14850
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5432
# --------------------------------
# Pulling data from PurpleAir Device ID 5433
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18297
# --------------------------------
# Pulling data from PurpleAir Device ID 39797
# --------------------------------
# Pulling data from PurpleAir Device ID 39798
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18298
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36495
# --------------------------------
# Pulling data from PurpleAir Device ID 36496
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 26919
# --------------------------------
# Pulling data from PurpleAir Device ID 26920
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 38649
# --------------------------------
# Pulling data from PurpleAir Device ID 38650
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20727
# --------------------------------
# Pulling data from PurpleAir Device ID 20728
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25623
# --------------------------------
# Pulling data from PurpleAir Device ID 25624
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23505
# --------------------------------
# Pulling data from PurpleAir Device ID 23506
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 7390
# --------------------------------
# Pulling data from PurpleAir Device ID 7391
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22789
# --------------------------------
# Pulling data from PurpleAir Device ID 22790
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22375
# --------------------------------
# Pulling data from PurpleAir Device ID 22376
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 72
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 1718
# --------------------------------
# Pulling data from PurpleAir Device ID 1719
# --------------------------------
# Pulling data from PurpleAir Device ID 28344
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2667
# --------------------------------
# Pulling data from PurpleAir Device ID 2668
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18625
# --------------------------------
# Pulling data from PurpleAir Device ID 18626
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18645
# --------------------------------
# Pulling data from PurpleAir Device ID 18646
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18647
# --------------------------------
# Pulling data from PurpleAir Device ID 18648
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 3637
# --------------------------------
# Pulling data from PurpleAir Device ID 3638
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25069
# --------------------------------
# Pulling data from PurpleAir Device ID 25070
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 39849
# --------------------------------
# Pulling data from PurpleAir Device ID 39850
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 35717
# --------------------------------
# Pulling data from PurpleAir Device ID 35718
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4770
# --------------------------------
# Pulling data from PurpleAir Device ID 4771
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 20159
# --------------------------------
# Pulling data from PurpleAir Device ID 20160
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34285
# --------------------------------
# Pulling data from PurpleAir Device ID 34286
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43615
# --------------------------------
# Pulling data from PurpleAir Device ID 43616
# Missing field/results... skipping.
# --------------------------------
# ...
# Pulling data from PurpleAir Device ID 14904
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22449
# --------------------------------
# Pulling data from PurpleAir Device ID 22450
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15029
# --------------------------------
# Pulling data from PurpleAir Device ID 15030
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 40181
# --------------------------------
# Pulling data from PurpleAir Device ID 40182
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21235
# --------------------------------
# Pulling data from PurpleAir Device ID 21236
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4177
# --------------------------------
# Pulling data from PurpleAir Device ID 4178
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34605
# --------------------------------
# Pulling data from PurpleAir Device ID 34606
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 44465
# --------------------------------
# Pulling data from PurpleAir Device ID 43843
# --------------------------------
# Pulling data from PurpleAir Device ID 43844
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 44466
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19533
# --------------------------------
# Pulling data from PurpleAir Device ID 19534
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 314
# --------------------------------
# Pulling data from PurpleAir Device ID 315
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 25561
# --------------------------------
# Pulling data from PurpleAir Device ID 25562
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18577
# --------------------------------
# Pulling data from PurpleAir Device ID 18578
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31237
# --------------------------------
# Pulling data from PurpleAir Device ID 31238
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36681
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36682
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 15179
# --------------------------------
# Pulling data from PurpleAir Device ID 15180
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43119
# --------------------------------
# Pulling data from PurpleAir Device ID 43120
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27095
# --------------------------------
# Pulling data from PurpleAir Device ID 27096
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 8840
# --------------------------------
# Pulling data from PurpleAir Device ID 8841
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 1618
# --------------------------------
# Pulling data from PurpleAir Device ID 1619
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36757
# --------------------------------
# Pulling data from PurpleAir Device ID 36758
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36015
# --------------------------------
# Pulling data from PurpleAir Device ID 36016
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37255
# --------------------------------
# Pulling data from PurpleAir Device ID 37256
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28899
# --------------------------------
# Pulling data from PurpleAir Device ID 28900
# --------------------------------
# Pulling data from PurpleAir Device ID 17133
# --------------------------------
# Pulling data from PurpleAir Device ID 17134
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 17151
# --------------------------------
# Pulling data from PurpleAir Device ID 17152
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12218
# --------------------------------
# Pulling data from PurpleAir Device ID 12219
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 28303
# --------------------------------
# Pulling data from PurpleAir Device ID 28304
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19463
# --------------------------------
# Pulling data from PurpleAir Device ID 19464
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 16119
# --------------------------------
# Pulling data from PurpleAir Device ID 16120
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 19491
# --------------------------------
# Pulling data from PurpleAir Device ID 19492
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 37083
# --------------------------------
# Pulling data from PurpleAir Device ID 37084
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 5256
# --------------------------------
# Pulling data from PurpleAir Device ID 5257
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6588
# --------------------------------
# Pulling data from PurpleAir Device ID 6589
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 14043
# --------------------------------
# Pulling data from PurpleAir Device ID 14044
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 4588
# --------------------------------
# Pulling data from PurpleAir Device ID 4589
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30905
# --------------------------------
# Pulling data from PurpleAir Device ID 30906
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18167
# --------------------------------
# Pulling data from PurpleAir Device ID 18168
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6674
# --------------------------------
# Pulling data from PurpleAir Device ID 6675
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31007
# --------------------------------
# Pulling data from PurpleAir Device ID 31008
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30985
# --------------------------------
# Pulling data from PurpleAir Device ID 30986
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18173
# --------------------------------
# Pulling data from PurpleAir Device ID 18174
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 6060
# --------------------------------
# Pulling data from PurpleAir Device ID 6061
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30843
# --------------------------------
# Pulling data from PurpleAir Device ID 30844
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18033
# --------------------------------
# Pulling data from PurpleAir Device ID 18034
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 30427
# --------------------------------
# Pulling data from PurpleAir Device ID 30428
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27051
# --------------------------------
# Pulling data from PurpleAir Device ID 27052
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27017
# --------------------------------
# Pulling data from PurpleAir Device ID 27018
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31829
# --------------------------------
# Pulling data from PurpleAir Device ID 31830
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27519
# --------------------------------
# Pulling data from PurpleAir Device ID 27520
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27539
# --------------------------------
# Pulling data from PurpleAir Device ID 27540
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27573
# --------------------------------
# Pulling data from PurpleAir Device ID 27574
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27547
# --------------------------------
# Pulling data from PurpleAir Device ID 27548
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27571
# --------------------------------
# Pulling data from PurpleAir Device ID 27572
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27455
# --------------------------------
# Pulling data from PurpleAir Device ID 27456
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27463
# --------------------------------
# Pulling data from PurpleAir Device ID 27464
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27511
# --------------------------------
# Pulling data from PurpleAir Device ID 27512
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27569
# --------------------------------
# Pulling data from PurpleAir Device ID 27570
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27533
# --------------------------------
# Pulling data from PurpleAir Device ID 27534
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27491
# --------------------------------
# Pulling data from PurpleAir Device ID 27492
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27563
# --------------------------------
# Pulling data from PurpleAir Device ID 27564
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27395
# --------------------------------
# Pulling data from PurpleAir Device ID 27396
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27485
# --------------------------------
# Pulling data from PurpleAir Device ID 27486
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27183
# --------------------------------
# Pulling data from PurpleAir Device ID 27184
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 27567
# --------------------------------
# Pulling data from PurpleAir Device ID 27568
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43147
# --------------------------------
# Pulling data from PurpleAir Device ID 43148
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 11806
# --------------------------------
# Pulling data from PurpleAir Device ID 11807
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2833
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 2834
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 33289
# --------------------------------
# Pulling data from PurpleAir Device ID 33290
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34717
# --------------------------------
# Pulling data from PurpleAir Device ID 34718
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 12989
# --------------------------------
# Pulling data from PurpleAir Device ID 12990
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 22863
# --------------------------------
# Pulling data from PurpleAir Device ID 22864
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 31493
# --------------------------------
# Pulling data from PurpleAir Device ID 31494
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 36449
# --------------------------------
# Pulling data from PurpleAir Device ID 36450
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 34573
# --------------------------------
# Pulling data from PurpleAir Device ID 34574
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 43565
# --------------------------------
# Pulling data from PurpleAir Device ID 43566
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23267
# --------------------------------
# Pulling data from PurpleAir Device ID 23268
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 1086
# --------------------------------
# Pulling data from PurpleAir Device ID 1087
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 23795
# --------------------------------
# Pulling data from PurpleAir Device ID 23796
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 42121
# --------------------------------
# Pulling data from PurpleAir Device ID 42122
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 41969
# --------------------------------
# Pulling data from PurpleAir Device ID 41970
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 8506
# --------------------------------
# Pulling data from PurpleAir Device ID 8507
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 7506
# --------------------------------
# Pulling data from PurpleAir Device ID 7507
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 21994
# --------------------------------
# Pulling data from PurpleAir Device ID 21996
# Missing field/results... skipping.
# --------------------------------
# Pulling data from PurpleAir Device ID 18209
# --------------------------------
# Pulling data from PurpleAir Device ID 18210
# Missing field/results... skipping.
# --------------------------------

# %%
# purple_air_df = purple_air_df.drop(columns=['Index'])
purple_air_df.dtypes
purple_air_nozero_df = purple_air_df.loc[(purple_air_df['PM2_5 Value']!="")&(purple_air_df['Latitude']!="")]
locations = purple_air_nozero_df[["Latitude", "Longitude"]].astype(float)
PM = purple_air_nozero_df[['PM2_5 Value']].astype(float)

PM
# Out:
#       PM2_5 Value
# 0            1.52
# 1            0.22
# 2           13.03
# 3           11.73
# 4            4.07
# ...           ...
# 9995         2.19
# 9996         1.75
# 9997         1.26
# 9998         0.15
# 9999         0.75
#
# [9160 rows x 1 columns]

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=PM['PM2_5 Value'],
                                dissipating=False, max_intensity=500,
                                point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
